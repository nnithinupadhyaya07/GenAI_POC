# %%
print("Mamba Mentality")

# %% [markdown]
# ### Appointments Dataset

# %%
appointments_df = spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/project/raw/raw/raw_hc/appointments/appointments_data_2025_02_21.csv")
appointments_df.display()

# %% [markdown]
# ### LabResults Dataset

# %%
labresults_df = spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/project/raw/raw/raw_hc/lab_results/lab_results_data_2025_02_21.csv")
labresults_df.display()

# %% [markdown]
# ### Medical_History Dataset

# %%
medical_history_df = spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/project/raw/raw/raw_hc/medical_history/medical_history_2025_02_21.csv")
medical_history_df.display()

# %% [markdown]
# ### Medication Dataset

# %%
medication_df = spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/project/raw/raw/raw_hc/medication/medication_data_2025_02_21.csv")
medication_df.display()

# %% [markdown]
# ### Patient Dataset

# %%
patient_df = spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/project/raw/raw/raw_hc/patient/patient_data_2025_02_21.csv")
patient_df.display()

# %% [markdown]
# ### Symptoms Dataset

# %%
symptoms_df = spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/project/raw/raw/raw_hc/symptoms/symptons_data_2025_02_21.csv")
symptoms_df.display()
